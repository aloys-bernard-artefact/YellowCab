# %% [markdown]
# ## Use Case Overview:
#
# The objective of this notebook is to predict the duration of NYC taxi trips. \
# We use data related to yellow or green taxis to train a simple prediction model.
#
# In this notebook, we use:
#
# - Yellow taxi data from January 2021 for model training.
# - Data from February 2021 to test the model (make predictions).
#
# **Features for Model Training**:
# - `PULocationID`: The taxi pickup location ID
# - `DOLocationID`: The taxi dropoff location ID
# - `passenger_count`: The number of passengers in the taxi
#
# **Target to Predict**: The duration of the trip

# %% [markdown]
# ### Data
# Data for the whole course can be downloaded following this [link](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page) or using the following code:

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/aloys.bernard/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown
import os

DATA_FOLDER = "../data"
train_path = f"{DATA_FOLDER}/yellow_tripdata_2021-01.parquet"
test_path = f"{DATA_FOLDER}/yellow_tripdata_2021-02.parquet"
predict_path = f"{DATA_FOLDER}/yellow_tripdata_2021-03.parquet"


if not os.path.exists(DATA_FOLDER):
    os.makedirs(DATA_FOLDER)
    print(f"New directory {DATA_FOLDER} created!")

    gdown.download(
        "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet",
        train_path,
        quiet=False,
    )
    gdown.download(
        "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-02.parquet",
        test_path,
        quiet=False,
    )
    gdown.download(
        "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-03.parquet",
        predict_path,
        quiet=False,
    )

# %%
import os

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, root_mean_squared_error
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# **Info** : <p style=color:green>Using large amounts of data in jupyter notebook, some cell can take some time to run<p/>

# %% [markdown]
# # 1 - Load data

# %%
DATA_FOLDER = "../data"

train_df = pd.read_parquet(os.path.join(DATA_FOLDER, "yellow_tripdata_2021-01.parquet"))

# %%
train_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5        0.00           0.0
# 1             2          3.0    0.5      0.5        0.00           0.0
# 2             1         42.0    0.5      0.5        8.65           0.0
# 3             1         29.0    0.5      0.5        6.05           0.0
# 4             1         16.5    0.5      0.5        4.06           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.3         11.80                   2.5          NaN
# 1                    0.3          4.30                   0.0          NaN
# 2                    0.3         51.95                   0.0          NaN
# 3                    0.3         36.35                   0.0          NaN
# 4                    0.3         24.36                   2.5          NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1369769 entries, 0 to 1369768
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1369769 non-null  int64
#  1   tpep_pickup_datetime   1369769 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  1369769 non-null  datetime64[us]
#  3   passenger_count        1271417 non-null  float64
#  4   trip_distance          1369769 non-null  float64
#  5   RatecodeID             1271417 non-null  float64
#  6   store_and_fwd_flag     1271417 non-null  object
#  7   PULocationID           1369769 non-null  int64
#  8   DOLocationID           1369769 non-null  int64
#  9   payment_type           1369769 non-null  int64
#  10  fare_amount            1369769 non-null  float64
#  11  extra                  1369769 non-null  float64
#  12  mta_tax                1369769 non-null  float64
#  13  tip_amount             1369769 non-null  float64
#  14  tolls_amount           1369769 non-null  float64
#  15  improvement_surcharge  1369769 non-null  float64
#  16  total_amount           1369769 non-null  float64
#  17  congestion_surcharge   1271417 non-null  float64
#  18  airport_fee            5 non-null        float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# memory usage: 198.6+ MB

# %%
train_df.isnull().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count            98352
# trip_distance                  0
# RatecodeID                 98352
# store_and_fwd_flag         98352
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge       98352
# airport_fee              1369764
# dtype: int64

# %% [markdown]
# # 2 - Prepare the data

# %% [markdown]
# ## 2-1 Compute the target

# %% [markdown]
# The dataset contains pickup and dropoff time but not the duration itself. \
# We compute the duration of a taxi trip in minutes using these two variables.

# %%
def compute_target(df):
    df["duration"] = df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"]
    df["duration"] = df["duration"].dt.total_seconds() / 60
    return df


train_df = compute_target(train_df)

# %% [markdown]
# We can visualise how the duration is distributed :

# %%
train_df["duration"].describe()
# Out:
# count    1.369769e+06
# mean     1.391168e+01
# std      1.312006e+02
# min     -1.350846e+05
# 25%      5.566667e+00
# 50%      9.066667e+00
# 75%      1.461667e+01
# max      2.881770e+04
# Name: duration, dtype: float64

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111)
sns.histplot(train_df.duration, ax=ax);

# %% [markdown]
# We notice that there are negative durations and trips that last 6 hours. \
# We will proceed to remove outliers and narrow the scope to trips lasting between 1 minute and 1 hour.

# %%
MIN_DURATION = 1
MAX_DURATION = 60


def filter_outliers(df, min_duration=MIN_DURATION, max_duration=MAX_DURATION):
    df = df[df["duration"].between(min_duration, max_duration)]
    return df


train_df = filter_outliers(train_df)

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111)
sns.histplot(train_df.duration, ax=ax);

# %% [markdown]
# ## 2-2 Prepare features

# %% [markdown]
# ### 2-2-1 Categorical features

# %% [markdown]
# We will encode discrete variables as strings and then proceed to extracting the features and the target in order to train two models:

# %%
CATEGORICAL_COLS = ["PULocationID", "DOLocationID", "passenger_count"]


def encode_categorical_cols(df):
    df[CATEGORICAL_COLS] = df[CATEGORICAL_COLS].fillna(-1).astype("int")
    df[CATEGORICAL_COLS] = df[CATEGORICAL_COLS].astype("category")
    return df


train_df = encode_categorical_cols(train_df)

# %%
def extract_x_y(df, dv=None):
    dicts = df[CATEGORICAL_COLS].to_dict(orient="records")
    if dv is None:
        dv = DictVectorizer()
        dv.fit(dicts)
    X = dv.transform(dicts)
    y = df["duration"].values
    return X, y, dv


X_train, y_train, dv = extract_x_y(train_df)

# %% [markdown]
# # 3 - Train model

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# ~ 2.5 minutes
rf = RandomForestRegressor(n_estimators=100, max_depth=11, max_features="sqrt", random_state=1, n_jobs=-1)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=11, max_features='sqrt', n_jobs=-1,
#                       random_state=1)

# %% [markdown]
# # 4 - Evaluate model

# %%
def compute_metrics(y, y_pred):
    metrics = {
        "rmse": (y, y_pred, squared=False),
        "mape": mean_absolute_percentage_error(y, y_pred),
    }
    return metrics
# Out:
#   Cell In[17], line 3
#     "rmse": (y, y_pred, squared=False),
#                         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# ## 4-1 On train data

# %%
y_pred_lr = lr.predict(X_train)
y_pred_rf = rf.predict(X_train)
compute_metrics(y_train, y_pred_lr), compute_metrics(y_train, y_pred_rf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 y_pred_lr = lr.predict(X_train)
#       2 y_pred_rf = rf.predict(X_train)
# ----> 3 compute_metrics(y_train, y_pred_lr), compute_metrics(y_train, y_pred_rf)
#
# Cell In[18], line 3, in compute_metrics(y, y_pred)
#       1 def compute_metrics(y, y_pred):
#       2     metrics = {
# ----> 3         "rmse": mean_squared_error(y, y_pred, squared=False),
#       4         "mape": mean_absolute_percentage_error(y, y_pred),
#       5     }
#       6     return metrics
#
# File ~/.pyenv/versions/3.10.12/envs/yellowcab/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:194, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
# --> 194 params = func_sig.bind(*args, **kwargs)
#     195 params.apply_defaults()
#     197 # ignore self/cls and positional/keyword markers
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/inspect.py:3186, in Signature.bind(self, *args, **kwargs)
#    3181 def bind(self, /, *args, **kwargs):
#    3182     """Get a BoundArguments object, that maps the passed `args`
#    3183     and `kwargs` to the function's signature.  Raises `TypeError`
#    3184     if the passed arguments can not be bound.
#    3185     """
# -> 3186     return self._bind(args, kwargs)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/inspect.py:3175, in Signature._bind(self, args, kwargs, partial)
#    3173         arguments[kwargs_param.name] = kwargs
#    3174     else:
# -> 3175         raise TypeError(
#    3176             'got an unexpected keyword argument {arg!r}'.format(
#    3177                 arg=next(iter(kwargs))))
#    3179 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'

# %% [markdown]
# ## 4-2 On test data

# %%
test_df = pd.read_parquet(os.path.join(DATA_FOLDER, "yellow_tripdata_2021-02.parquet"))

# %%
test_df = compute_target(test_df)
test_df = filter_outliers(test_df)
test_df = encode_categorical_cols(test_df)
X_test, y_test, _ = extract_x_y(test_df, dv=dv)

# %%
y_pred_test_lr = lr.predict(X_test)
y_pred_test_rf = rf.predict(X_test)
compute_metrics(y_test, y_pred_test_lr), compute_metrics(y_test, y_pred_test_rf)

# %% [markdown]
# # Saving the model

# %%
import pickle
MODEL_FOLDER = "../models"
if not os.path.exists(MODEL_FOLDER):
    os.makedirs(MODEL_FOLDER)
    print(f"New directory {MODEL_FOLDER} created!")
with open(f"{MODEL_FOLDER}/linear_regression.pkl", "wb") as f:
    pickle.dump(lr, f)
with open(f"{MODEL_FOLDER}/dv.pkl", "wb") as f:
    pickle.dump(dv, f)

# %% [markdown]
# # Conclusion
#
# * What can you say of the trained models?
# * If you had to improve these models, what would you do?
